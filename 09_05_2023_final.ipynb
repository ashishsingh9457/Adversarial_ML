# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishsingh9457/Adversarial_ML/blob/main/09_05_2023_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ashishsingh9457/mini_project1.git
# Out:
# Cloning into 'mini_project1'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 56 (delta 0), reused 0 (delta 0), pack-reused 55
# Unpacking objects: 100% (56/56), 25.41 MiB | 10.89 MiB/s, done.

# %%
cd mini_project1
# Out:
# /content/mini_project1

# %%
! python fgsm.py
# Out:
# 2023-05-09 04:36:23.869382: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-09 04:36:26.024771: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# 11490434/11490434 [==============================] - 0s 0us/step
# (60000, 10)
# (60000,)
# (10000, 10)
# (10000,)
#
# Evaluating on original data
# training SVM...
# Prediction on original data=  98.19
# 2023-05-09 04:39:13.522442: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1730560000 exceeds 10% of free system memory.
# 2023-05-09 04:39:16.999186: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1730560000 exceeds 10% of free system memory.
# ...

# %%
! python ifgsm.py
# Out:
# 2023-05-09 04:46:27.856989: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-09 04:46:29.204221: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (60000, 10)
# (60000,)
# (10000, 10)
# (10000,)
#
# Evaluating on original data
# training SVM...
# Prediction on original data=  98.19
# 2023-05-09 04:49:06.702039: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1730560000 exceeds 10% of free system memory.
# 2023-05-09 04:49:08.921139: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1730560000 exceeds 10% of free system memory.
# ...

# %%
! python mfgsm.py
# Out:
# 2023-05-09 04:55:02.567008: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-09 04:55:04.044599: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
# Evaluating on original data
# training SVM...
# Prediction on original data=  98.19
# 2023-05-09 04:58:04.926958: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1730560000 exceeds 10% of free system memory.
# 2023-05-09 04:58:08.917650: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1730560000 exceeds 10% of free system memory.
# 2023-05-09 04:58:10.856117: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1730560000 exceeds 10% of free system memory.
# ...

# %%
cd ..
# Out:
# /content

# %%
pwd
# Out:
# '/content'

# %%
cd ..
# Out:
# /content

# %%
# !zip -r mini2.zip mini_project1/
# Out:
#   adding: mini_project1/ (stored 0%)
#   adding: mini_project1/PGD_ad-fgsm0.1.png (deflated 16%)
#   adding: mini_project1/pgd_ad.py (deflated 62%)
#   adding: mini_project1/new_features.gz (deflated 0%)
#   adding: mini_project1/M-fgsm0.2.png (deflated 17%)
#   adding: mini_project1/PGD_ad-fgsm0.2.png (deflated 18%)
#   adding: mini_project1/fgsm0.1.png (deflated 19%)
#   adding: mini_project1/fgsm0.03.png (deflated 17%)
#   adding: mini_project1/I-fgsm0.05.png (deflated 18%)
#   adding: mini_project1/objectives.py (deflated 65%)
#   adding: mini_project1/M-fgsm0.05.png (deflated 18%)
#   adding: mini_project1/fgsm0.01.png (deflated 17%)
#   adding: mini_project1/model_params.gz (deflated 0%)
#   adding: mini_project1/fgsm0.png (deflated 22%)
#   adding: mini_project1/fgsm0.05.png (deflated 17%)
#   adding: mini_project1/models.py (deflated 81%)
#   adding: mini_project1/fgsm0.02.png (deflated 17%)
#   adding: mini_project1/ifgsm.py (deflated 63%)
# ...

# %%
from google.colab import files
files.download("mini2.zip")

# %%
cd mini_project1/
# Out:
# [Errno 2] No such file or directory: 'mini_project1/'
# /content/mini_project1

# %%
# !python pgd_ad.py
# Out:
# 2023-05-09 06:57:35.076386: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-09 06:57:36.289605: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
# Evaluating on original data
# training SVM...
# Prediction on original data=  98.19
# 2023-05-09 07:00:18.313525: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1730560000 exceeds 10% of free system memory.
# 2023-05-09 07:00:19.934943: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1730560000 exceeds 10% of free system memory.
# 2023-05-09 07:00:21.469880: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1730560000 exceeds 10% of free system memory.
# ...
